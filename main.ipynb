# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import statsmodels.api as sm

# %%
xlsx_path = 'excel/Athletes_summer_games.xlsx'
df = pd.read_excel(xlsx_path)
print(df.head(5))
# Out:
#    Id                                Name Sex   Age            Team  NOC  \
# 0   0                           A Dijiang   M  24.0           China  CHN
# 1   1                            A Lamusi   M  23.0           China  CHN
# 2   2                 Gunnar Nielsen Aaby   M  24.0         Denmark  DEN
# 3   3                Edgar Lindenau Aabye   M  34.0  Denmark/Sweden  DEN
# 4  26  Cornelia "Cor" Aalten (-Strannood)   F  18.0     Netherlands  NED
#
#          Games    Year  Season         City       Sport  \
# 0  1992 Summer  1992.0  Summer    Barcelona  Basketball
# 1  2012 Summer  2012.0  Summer       London        Judo
# 2  1920 Summer  1920.0  Summer    Antwerpen    Football
# 3  1900 Summer  1900.0  Summer        Paris  Tug-Of-War
# 4  1932 Summer  1932.0  Summer  Los Angeles   Athletics
#
#                           Event Medal
# 0   Basketball Men's Basketball   NaN
# 1  Judo Men's Extra-Lightweight   NaN
# 2       Football Men's Football   NaN
# 3   Tug-Of-War Men's Tug-Of-War  Gold
# 4  Athletics Women's 100 metres   NaN

# %%
print(f"Number of columns and rows: {df.shape}")
print(f"Name of columns: {df.columns}")
# Out:
# Number of columns and rows: (237673, 13)
# Name of columns: Index(['Id', 'Name', 'Sex', 'Age', 'Team', 'NOC', 'Games', 'Year', 'Season',
#        'City', 'Sport', 'Event', 'Medal'],
#       dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 237673 entries, 0 to 237672
# Data columns (total 13 columns):
#  #   Column  Non-Null Count   Dtype
# ---  ------  --------------   -----
#  0   Id      237673 non-null  int64
#  1   Name    237673 non-null  object
#  2   Sex     237672 non-null  object
#  3   Age     228483 non-null  float64
#  4   Team    237672 non-null  object
#  5   NOC     237672 non-null  object
#  6   Games   237672 non-null  object
#  7   Year    237672 non-null  float64
#  8   Season  237672 non-null  object
#  9   City    237672 non-null  object
#  10  Sport   237672 non-null  object
#  11  Event   237672 non-null  object
#  12  Medal   36537 non-null   object
# dtypes: float64(2), int64(1), object(10)
# memory usage: 23.6+ MB

# %%
df.describe()
# Out:
#                   Id            Age           Year
# count  237673.000000  228483.000000  237672.000000
# mean   126947.990521      25.746279    1979.096074
# std     82093.460104       6.638733      31.783923
# min         0.000000      10.000000    1896.000000
# 25%     52693.000000      21.000000    1960.000000
# 50%    126221.000000      25.000000    1988.000000
# 75%    198214.000000      29.000000    2004.000000
# max    271110.000000      97.000000    2020.000000

# %%
df['Medal'].value_counts()
# Out:
# Bronze    12276
# Gold      12259
# Silver    12002
# Name: Medal, dtype: int64

# %%
df['Year'].value_counts()
df['Name']
# Out:
# 'Gunnar Nielsen Aaby'

# %%
df.hist(bins=50,figsize=(15,12))
# Out:
# array([[<AxesSubplot:title={'center':'Id'}>,
#         <AxesSubplot:title={'center':'Age'}>],
#        [<AxesSubplot:title={'center':'Year'}>, <AxesSubplot:>]],
#       dtype=object)
